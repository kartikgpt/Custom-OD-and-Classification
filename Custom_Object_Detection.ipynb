# %% [markdown]
# ## **Cloning TFOD 2.0 Github**

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 68137, done.
# remote: Total 68137 (delta 0), reused 0 (delta 0), pack-reused 68137
# Receiving objects: 100% (68137/68137), 576.49 MiB | 22.81 MiB/s, done.
# Resolving deltas: 100% (47868/47868), done.

# %%
pwd
# Out:
# '/content'

# %%
cd /content/models/research
# Out:
# /content/models/research

# %%
pwd
# Out:
# '/content/models/research'

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# !git clone https://github.com/cocodataset/cocoapi.git
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975
# Receiving objects: 100% (975/975), 11.72 MiB | 20.63 MiB/s, done.
# Resolving deltas: 100% (576/576), done.

# %%
cd cocoapi/PythonAPI
# Out:
# /content/models/research/cocoapi/PythonAPI

# %%
# !make
# Out:
# python setup.py build_ext --inplace
# running build_ext
# cythoning pycocotools/_mask.pyx to pycocotools/_mask.c
# /usr/local/lib/python3.7/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/models/research/cocoapi/PythonAPI/pycocotools/_mask.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'pycocotools._mask' extension
# creating build
# creating build/common
# creating build/temp.linux-x86_64-3.7
# creating build/temp.linux-x86_64-3.7/pycocotools
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-Y7dWVB/python3.7-3.7.12=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-Y7dWVB/python3.7-3.7.12=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/numpy/core/include -I../common -I/usr/include/python3.7m -c ../common/maskApi.c -o build/temp.linux-x86_64-3.7/../common/maskApi.o -Wno-cpp -Wno-unused-function -std=c99
# ../common/maskApi.c: In function ‘rleDecode’:
# ../common/maskApi.c:46:7: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#        for( k=0; k<R[i].cnts[j]; k++ ) *(M++)=v; v=!v; }}
#        ^~~
# ../common/maskApi.c:46:49: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#        for( k=0; k<R[i].cnts[j]; k++ ) *(M++)=v; v=!v; }}
#                                                  ^
# ../common/maskApi.c: In function ‘rleFrPoly’:
# ../common/maskApi.c:166:3: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#    for(j=0; j<k; j++) x[j]=(int)(scale*xy[j*2+0]+.5); x[k]=x[0];
#    ^~~
# ../common/maskApi.c:166:54: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#    for(j=0; j<k; j++) x[j]=(int)(scale*xy[j*2+0]+.5); x[k]=x[0];
#                                                       ^
# ../common/maskApi.c:167:3: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#    for(j=0; j<k; j++) y[j]=(int)(scale*xy[j*2+1]+.5); y[k]=y[0];
#    ^~~
# ../common/maskApi.c:167:54: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#    for(j=0; j<k; j++) y[j]=(int)(scale*xy[j*2+1]+.5); y[k]=y[0];
#                                                       ^
# ../common/maskApi.c: In function ‘rleToString’:
# ../common/maskApi.c:212:7: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#        if(more) c |= 0x20; c+=48; s[p++]=c;
#        ^~
# ../common/maskApi.c:212:27: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#        if(more) c |= 0x20; c+=48; s[p++]=c;
#                            ^
# ../common/maskApi.c: In function ‘rleFrString’:
# ../common/maskApi.c:220:3: warning: this ‘while’ clause does not guard... [-Wmisleading-indentation]
#    while( s[m] ) m++; cnts=malloc(sizeof(uint)*m); m=0;
#    ^~~~~
# ../common/maskApi.c:220:22: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘while’
#    while( s[m] ) m++; cnts=malloc(sizeof(uint)*m); m=0;
#                       ^~~~
# ../common/maskApi.c:228:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if(m>2) x+=(long) cnts[m-2]; cnts[m++]=(uint) x;
#      ^~
# ../common/maskApi.c:228:34: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if(m>2) x+=(long) cnts[m-2]; cnts[m++]=(uint) x;
#                                   ^~~~
# ../common/maskApi.c: In function ‘rleToBbox’:
# ../common/maskApi.c:141:31: warning: ‘xp’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#        if(j%2==0) xp=x; else if(xp<x) { ys=0; ye=h-1; }
#                                ^
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-Y7dWVB/python3.7-3.7.12=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-Y7dWVB/python3.7-3.7.12=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/numpy/core/include -I../common -I/usr/include/python3.7m -c pycocotools/_mask.c -o build/temp.linux-x86_64-3.7/pycocotools/_mask.o -Wno-cpp -Wno-unused-function -std=c99
# creating build/lib.linux-x86_64-3.7
# creating build/lib.linux-x86_64-3.7/pycocotools
# x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fdebug-prefix-map=/build/python3.7-Y7dWVB/python3.7-3.7.12=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/../common/maskApi.o build/temp.linux-x86_64-3.7/pycocotools/_mask.o -o build/lib.linux-x86_64-3.7/pycocotools/_mask.cpython-37m-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-3.7/pycocotools/_mask.cpython-37m-x86_64-linux-gnu.so -> pycocotools
# rm -rf build

# %%
cp -r pycocotools /content/models/research

# %% [markdown]
# ### Install the Object Detection API

# %%
cd ..
# Out:
# /content/models/research/cocoapi

# %%
cd ..
# Out:
# /content/models/research

# %%
cp object_detection/packages/tf2/setup.py .

# %%
# !python -m pip install .
# Out:
# Processing /content/models/research
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
# Collecting apache-beam
#   Downloading apache_beam-2.34.0-cp37-cp37m-manylinux2010_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 8.7 MB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (4.2.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (3.2.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.29.24)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.5.5)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 49.3 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.0.3)
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.1.5)
# Collecting tf-models-official>=2.5.1
#   Downloading tf_models_official-2.7.0-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 36.6 MB/s
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.23.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.1 MB)
#      |████████████████████████████████| 23.1 MB 54.5 MB/s
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.7.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.12.8)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.15.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 39.3 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 46.1 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.0 MB/s
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.0.1)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.12)
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.5.4.60-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.6 MB)
#      |████████████████████████████████| 47.6 MB 2.4 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 37.7 MB/s
# Requirement already satisfied: tensorflow>=2.7.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.7.0)
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.7.0-py2.py3-none-any.whl (213 kB)
#      |████████████████████████████████| 213 kB 47.6 MB/s
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.19.5)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.8)
# Collecting tensorflow-text>=2.7.0
#   Downloading tensorflow_text-2.7.3-cp37-cp37m-manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 39.3 MB/s
# Collecting py-cpuinfo>=3.3.0
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 9.0 MB/s
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 8.8 MB/s
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: google-auth>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.35.0)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.26.3)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.17.4)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.0.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2018.9)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (21.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.53.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.23.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (57.4.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.17.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.62.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2021.10.8)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (5.0.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.4)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (1.42.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (2.7.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (0.22.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (3.10.0.2)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.2)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (1.13.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (2.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (12.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (2.7.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (1.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (3.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.7.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.1)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.6)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (3.12.1)
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.6.0-py3-none-any.whl (33 kB)
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 46.2 MB/s
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.3.0)
# Collecting future<1.0.0,>=0.18.2
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 46.1 MB/s
# Collecting requests<3.0.0dev,>=2.18.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 846 kB/s
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Collecting fastavro<2,>=0.21.4
#   Downloading fastavro-1.4.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 47.4 MB/s
# Requirement already satisfied: pyarrow<6.0.0,>=0.15.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (3.0.0)
# Collecting avro-python3
#   Downloading avro-python3-1.9.2.1.tar.gz (37 kB)
# Collecting orjson<4.0
#   Downloading orjson-3.6.5-cp37-cp37m-manylinux_2_24_x86_64.whl (247 kB)
#      |████████████████████████████████| 247 kB 46.7 MB/s
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.0.8)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (4.1.2.30)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (0.8.9)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (2019.12.20)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.0.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.0.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.7.1)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.4.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.4.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (21.2.0)
# Collecting tensorflow-io-gcs-filesystem>=0.21.0
#   Downloading tensorflow_io_gcs_filesystem-0.23.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 34.3 MB/s
# Building wheels for collected packages: object-detection, py-cpuinfo, avro-python3, dill, future, seqeval
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1683460 sha256=0095aaa8ea21fa5d97f1e59088a011484745974de598443a95b4827d5398bcd8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c1vzc8iu/wheels/fa/a4/d2/e9a5057e414fd46c8e543d2706cd836d64e1fcd9eccceb2329
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22258 sha256=7a0aedd9b96d81046864b6ef10ac6d6d5dc2373f814d9bfb574c3483cf906afd
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.9.2.1-py3-none-any.whl size=43512 sha256=a2f53553374520dbae896cd0fbff8895b21aa10400726df415bf219d846194ea
#   Stored in directory: /root/.cache/pip/wheels/bc/49/5f/fdb5b9d85055c478213e0158ac122b596816149a02d82e0ab1
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78546 sha256=7ab851065ab9986c03a19c4f13a08fd6971f0994400f6b7b0f686c8aa7982dd8
#   Stored in directory: /root/.cache/pip/wheels/a4/61/fd/c57e374e580aa78a45ed78d5859b3a44436af17e22ca53284f
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=8b45f98350eb81df959eafecc5c20b13b2b33ddd5db40d4d87affbe897ba4394
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16181 sha256=6a17bd01e49fc355486af9d0b96013daca8f1ab77addce43a537985fc8d76e81
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built object-detection py-cpuinfo avro-python3 dill future seqeval
# Installing collected packages: requests, tensorflow-io-gcs-filesystem, portalocker, future, dill, colorama, tf-slim, tensorflow-text, tensorflow-model-optimization, tensorflow-addons, seqeval, sentencepiece, sacrebleu, pyyaml, py-cpuinfo, orjson, opencv-python-headless, hdfs, fastavro, avro-python3, tf-models-official, tensorflow-io, lvis, apache-beam, object-detection
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.22.0
#     Uninstalling tensorflow-io-gcs-filesystem-0.22.0:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.22.0
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.4
#     Uninstalling dill-0.3.4:
#       Successfully uninstalled dill-0.3.4
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# multiprocess 0.70.12.2 requires dill>=0.3.4, but you have dill 0.3.1.1 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed apache-beam-2.34.0 avro-python3-1.9.2.1 colorama-0.4.4 dill-0.3.1.1 fastavro-1.4.7 future-0.18.2 hdfs-2.6.0 lvis-0.5.3 object-detection-0.1 opencv-python-headless-4.5.4.60 orjson-3.6.5 portalocker-2.3.2 py-cpuinfo-8.0.0 pyyaml-6.0 requests-2.26.0 sacrebleu-2.0.0 sentencepiece-0.1.96 seqeval-1.2.2 tensorflow-addons-0.15.0 tensorflow-io-0.23.1 tensorflow-io-gcs-filesystem-0.23.1 tensorflow-model-optimization-0.7.0 tensorflow-text-2.7.3 tf-models-official-2.7.0 tf-slim-1.1.0

# %%
# From within TensorFlow/models/research/
# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# Running tests under Python 3.7.12: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2021-12-14 04:53:36.656137: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# W1214 04:53:37.092658 140532618450816 model_builder.py:1100] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 3.2s
# I1214 04:53:37.429952 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 3.2s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.64s
# I1214 04:53:38.068236 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.64s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.35s
# I1214 04:53:38.422230 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.35s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.33s
# I1214 04:53:38.753076 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.33s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.28s
# I1214 04:53:41.028918 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.28s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I1214 04:53:41.029909 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.03s
# I1214 04:53:41.056253 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# I1214 04:53:41.073667 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# I1214 04:53:41.091132 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.11s
# I1214 04:53:41.204331 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.11s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.13s
# I1214 04:53:41.334880 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.13s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.13s
# I1214 04:53:41.465050 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.13s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.14s
# I1214 04:53:41.603877 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.14s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.12s
# I1214 04:53:41.726247 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.12s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.04s
# I1214 04:53:41.762211 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.04s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I1214 04:53:41.988903 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b0
# I1214 04:53:41.989111 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 64
# I1214 04:53:41.989237 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 3
# I1214 04:53:41.991854 140532618450816 efficientnet_model.py:147] round_filter input=32 output=32
# I1214 04:53:42.014274 140532618450816 efficientnet_model.py:147] round_filter input=32 output=32
# I1214 04:53:42.014430 140532618450816 efficientnet_model.py:147] round_filter input=16 output=16
# I1214 04:53:42.091101 140532618450816 efficientnet_model.py:147] round_filter input=16 output=16
# I1214 04:53:42.091288 140532618450816 efficientnet_model.py:147] round_filter input=24 output=24
# I1214 04:53:42.296540 140532618450816 efficientnet_model.py:147] round_filter input=24 output=24
# I1214 04:53:42.296749 140532618450816 efficientnet_model.py:147] round_filter input=40 output=40
# I1214 04:53:42.488245 140532618450816 efficientnet_model.py:147] round_filter input=40 output=40
# I1214 04:53:42.488455 140532618450816 efficientnet_model.py:147] round_filter input=80 output=80
# I1214 04:53:42.935143 140532618450816 efficientnet_model.py:147] round_filter input=80 output=80
# I1214 04:53:42.935379 140532618450816 efficientnet_model.py:147] round_filter input=112 output=112
# I1214 04:53:43.208787 140532618450816 efficientnet_model.py:147] round_filter input=112 output=112
# I1214 04:53:43.209035 140532618450816 efficientnet_model.py:147] round_filter input=192 output=192
# I1214 04:53:43.602190 140532618450816 efficientnet_model.py:147] round_filter input=192 output=192
# I1214 04:53:43.602414 140532618450816 efficientnet_model.py:147] round_filter input=320 output=320
# I1214 04:53:43.694460 140532618450816 efficientnet_model.py:147] round_filter input=1280 output=1280
# I1214 04:53:43.730371 140532618450816 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1214 04:53:43.795243 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b1
# I1214 04:53:43.795493 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 88
# I1214 04:53:43.795629 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 4
# I1214 04:53:43.798668 140532618450816 efficientnet_model.py:147] round_filter input=32 output=32
# I1214 04:53:43.828137 140532618450816 efficientnet_model.py:147] round_filter input=32 output=32
# I1214 04:53:43.828369 140532618450816 efficientnet_model.py:147] round_filter input=16 output=16
# I1214 04:53:43.972108 140532618450816 efficientnet_model.py:147] round_filter input=16 output=16
# I1214 04:53:43.972300 140532618450816 efficientnet_model.py:147] round_filter input=24 output=24
# I1214 04:53:44.253748 140532618450816 efficientnet_model.py:147] round_filter input=24 output=24
# I1214 04:53:44.253994 140532618450816 efficientnet_model.py:147] round_filter input=40 output=40
# I1214 04:53:44.551132 140532618450816 efficientnet_model.py:147] round_filter input=40 output=40
# I1214 04:53:44.551358 140532618450816 efficientnet_model.py:147] round_filter input=80 output=80
# I1214 04:53:44.931282 140532618450816 efficientnet_model.py:147] round_filter input=80 output=80
# I1214 04:53:44.931478 140532618450816 efficientnet_model.py:147] round_filter input=112 output=112
# I1214 04:53:45.306304 140532618450816 efficientnet_model.py:147] round_filter input=112 output=112
# I1214 04:53:45.306531 140532618450816 efficientnet_model.py:147] round_filter input=192 output=192
# I1214 04:53:45.791977 140532618450816 efficientnet_model.py:147] round_filter input=192 output=192
# I1214 04:53:45.792176 140532618450816 efficientnet_model.py:147] round_filter input=320 output=320
# I1214 04:53:45.967998 140532618450816 efficientnet_model.py:147] round_filter input=1280 output=1280
# I1214 04:53:46.001343 140532618450816 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1214 04:53:46.076219 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b2
# I1214 04:53:46.076416 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 112
# I1214 04:53:46.076543 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 5
# I1214 04:53:46.079010 140532618450816 efficientnet_model.py:147] round_filter input=32 output=32
# I1214 04:53:46.096576 140532618450816 efficientnet_model.py:147] round_filter input=32 output=32
# I1214 04:53:46.096691 140532618450816 efficientnet_model.py:147] round_filter input=16 output=16
# I1214 04:53:46.234981 140532618450816 efficientnet_model.py:147] round_filter input=16 output=16
# I1214 04:53:46.235152 140532618450816 efficientnet_model.py:147] round_filter input=24 output=24
# I1214 04:53:46.533822 140532618450816 efficientnet_model.py:147] round_filter input=24 output=24
# I1214 04:53:46.534024 140532618450816 efficientnet_model.py:147] round_filter input=40 output=48
# I1214 04:53:46.818521 140532618450816 efficientnet_model.py:147] round_filter input=40 output=48
# I1214 04:53:46.818713 140532618450816 efficientnet_model.py:147] round_filter input=80 output=88
# I1214 04:53:47.175003 140532618450816 efficientnet_model.py:147] round_filter input=80 output=88
# I1214 04:53:47.175212 140532618450816 efficientnet_model.py:147] round_filter input=112 output=120
# I1214 04:53:47.571979 140532618450816 efficientnet_model.py:147] round_filter input=112 output=120
# I1214 04:53:47.572183 140532618450816 efficientnet_model.py:147] round_filter input=192 output=208
# I1214 04:53:48.226635 140532618450816 efficientnet_model.py:147] round_filter input=192 output=208
# I1214 04:53:48.226851 140532618450816 efficientnet_model.py:147] round_filter input=320 output=352
# I1214 04:53:48.437522 140532618450816 efficientnet_model.py:147] round_filter input=1280 output=1408
# I1214 04:53:48.477324 140532618450816 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1214 04:53:48.560275 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b3
# I1214 04:53:48.560509 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 160
# I1214 04:53:48.560650 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 6
# I1214 04:53:48.562765 140532618450816 efficientnet_model.py:147] round_filter input=32 output=40
# I1214 04:53:48.583409 140532618450816 efficientnet_model.py:147] round_filter input=32 output=40
# I1214 04:53:48.583599 140532618450816 efficientnet_model.py:147] round_filter input=16 output=24
# I1214 04:53:48.743767 140532618450816 efficientnet_model.py:147] round_filter input=16 output=24
# I1214 04:53:48.744047 140532618450816 efficientnet_model.py:147] round_filter input=24 output=32
# I1214 04:53:49.055966 140532618450816 efficientnet_model.py:147] round_filter input=24 output=32
# I1214 04:53:49.056170 140532618450816 efficientnet_model.py:147] round_filter input=40 output=48
# I1214 04:53:49.340922 140532618450816 efficientnet_model.py:147] round_filter input=40 output=48
# I1214 04:53:49.341117 140532618450816 efficientnet_model.py:147] round_filter input=80 output=96
# I1214 04:53:49.815042 140532618450816 efficientnet_model.py:147] round_filter input=80 output=96
# I1214 04:53:49.815250 140532618450816 efficientnet_model.py:147] round_filter input=112 output=136
# I1214 04:53:50.280349 140532618450816 efficientnet_model.py:147] round_filter input=112 output=136
# I1214 04:53:50.280582 140532618450816 efficientnet_model.py:147] round_filter input=192 output=232
# I1214 04:53:50.865974 140532618450816 efficientnet_model.py:147] round_filter input=192 output=232
# I1214 04:53:50.866187 140532618450816 efficientnet_model.py:147] round_filter input=320 output=384
# I1214 04:53:51.055174 140532618450816 efficientnet_model.py:147] round_filter input=1280 output=1536
# I1214 04:53:51.089908 140532618450816 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1214 04:53:51.173654 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b4
# I1214 04:53:51.173843 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 224
# I1214 04:53:51.173953 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 7
# I1214 04:53:51.175799 140532618450816 efficientnet_model.py:147] round_filter input=32 output=48
# I1214 04:53:51.193813 140532618450816 efficientnet_model.py:147] round_filter input=32 output=48
# I1214 04:53:51.193938 140532618450816 efficientnet_model.py:147] round_filter input=16 output=24
# I1214 04:53:51.339611 140532618450816 efficientnet_model.py:147] round_filter input=16 output=24
# I1214 04:53:51.339826 140532618450816 efficientnet_model.py:147] round_filter input=24 output=32
# I1214 04:53:51.725720 140532618450816 efficientnet_model.py:147] round_filter input=24 output=32
# I1214 04:53:51.725956 140532618450816 efficientnet_model.py:147] round_filter input=40 output=56
# I1214 04:53:52.094492 140532618450816 efficientnet_model.py:147] round_filter input=40 output=56
# I1214 04:53:52.094682 140532618450816 efficientnet_model.py:147] round_filter input=80 output=112
# I1214 04:53:52.665858 140532618450816 efficientnet_model.py:147] round_filter input=80 output=112
# I1214 04:53:52.666061 140532618450816 efficientnet_model.py:147] round_filter input=112 output=160
# I1214 04:53:53.228059 140532618450816 efficientnet_model.py:147] round_filter input=112 output=160
# I1214 04:53:53.228304 140532618450816 efficientnet_model.py:147] round_filter input=192 output=272
# I1214 04:53:53.979017 140532618450816 efficientnet_model.py:147] round_filter input=192 output=272
# I1214 04:53:53.979245 140532618450816 efficientnet_model.py:147] round_filter input=320 output=448
# I1214 04:53:54.439158 140532618450816 efficientnet_model.py:147] round_filter input=1280 output=1792
# I1214 04:53:54.472926 140532618450816 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1214 04:53:54.574630 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b5
# I1214 04:53:54.574843 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 288
# I1214 04:53:54.574944 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 7
# I1214 04:53:54.577986 140532618450816 efficientnet_model.py:147] round_filter input=32 output=48
# I1214 04:53:54.597495 140532618450816 efficientnet_model.py:147] round_filter input=32 output=48
# I1214 04:53:54.597716 140532618450816 efficientnet_model.py:147] round_filter input=16 output=24
# I1214 04:53:54.822421 140532618450816 efficientnet_model.py:147] round_filter input=16 output=24
# I1214 04:53:54.822641 140532618450816 efficientnet_model.py:147] round_filter input=24 output=40
# I1214 04:53:55.277861 140532618450816 efficientnet_model.py:147] round_filter input=24 output=40
# I1214 04:53:55.278065 140532618450816 efficientnet_model.py:147] round_filter input=40 output=64
# I1214 04:53:55.743076 140532618450816 efficientnet_model.py:147] round_filter input=40 output=64
# I1214 04:53:55.743298 140532618450816 efficientnet_model.py:147] round_filter input=80 output=128
# I1214 04:53:56.395630 140532618450816 efficientnet_model.py:147] round_filter input=80 output=128
# I1214 04:53:56.395849 140532618450816 efficientnet_model.py:147] round_filter input=112 output=176
# I1214 04:53:57.048304 140532618450816 efficientnet_model.py:147] round_filter input=112 output=176
# I1214 04:53:57.048495 140532618450816 efficientnet_model.py:147] round_filter input=192 output=304
# I1214 04:53:57.934311 140532618450816 efficientnet_model.py:147] round_filter input=192 output=304
# I1214 04:53:57.934505 140532618450816 efficientnet_model.py:147] round_filter input=320 output=512
# I1214 04:53:58.234124 140532618450816 efficientnet_model.py:147] round_filter input=1280 output=2048
# I1214 04:53:58.271703 140532618450816 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1214 04:53:58.383394 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b6
# I1214 04:53:58.383636 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 384
# I1214 04:53:58.383749 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 8
# I1214 04:53:58.385866 140532618450816 efficientnet_model.py:147] round_filter input=32 output=56
# I1214 04:53:58.405184 140532618450816 efficientnet_model.py:147] round_filter input=32 output=56
# I1214 04:53:58.405345 140532618450816 efficientnet_model.py:147] round_filter input=16 output=32
# I1214 04:53:58.639583 140532618450816 efficientnet_model.py:147] round_filter input=16 output=32
# I1214 04:53:58.639778 140532618450816 efficientnet_model.py:147] round_filter input=24 output=40
# I1214 04:53:59.182226 140532618450816 efficientnet_model.py:147] round_filter input=24 output=40
# I1214 04:53:59.182421 140532618450816 efficientnet_model.py:147] round_filter input=40 output=72
# I1214 04:53:59.789482 140532618450816 efficientnet_model.py:147] round_filter input=40 output=72
# I1214 04:53:59.789702 140532618450816 efficientnet_model.py:147] round_filter input=80 output=144
# I1214 04:54:00.515285 140532618450816 efficientnet_model.py:147] round_filter input=80 output=144
# I1214 04:54:00.515541 140532618450816 efficientnet_model.py:147] round_filter input=112 output=200
# I1214 04:54:01.554730 140532618450816 efficientnet_model.py:147] round_filter input=112 output=200
# I1214 04:54:01.554992 140532618450816 efficientnet_model.py:147] round_filter input=192 output=344
# I1214 04:54:02.663551 140532618450816 efficientnet_model.py:147] round_filter input=192 output=344
# I1214 04:54:02.663892 140532618450816 efficientnet_model.py:147] round_filter input=320 output=576
# I1214 04:54:02.977126 140532618450816 efficientnet_model.py:147] round_filter input=1280 output=2304
# I1214 04:54:03.015574 140532618450816 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1214 04:54:03.131972 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b7
# I1214 04:54:03.132203 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 384
# I1214 04:54:03.132306 140532618450816 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 8
# I1214 04:54:03.134255 140532618450816 efficientnet_model.py:147] round_filter input=32 output=64
# I1214 04:54:03.154242 140532618450816 efficientnet_model.py:147] round_filter input=32 output=64
# I1214 04:54:03.154375 140532618450816 efficientnet_model.py:147] round_filter input=16 output=32
# I1214 04:54:03.459655 140532618450816 efficientnet_model.py:147] round_filter input=16 output=32
# I1214 04:54:03.459904 140532618450816 efficientnet_model.py:147] round_filter input=24 output=48
# I1214 04:54:04.111016 140532618450816 efficientnet_model.py:147] round_filter input=24 output=48
# I1214 04:54:04.111263 140532618450816 efficientnet_model.py:147] round_filter input=40 output=80
# I1214 04:54:04.849888 140532618450816 efficientnet_model.py:147] round_filter input=40 output=80
# I1214 04:54:04.850152 140532618450816 efficientnet_model.py:147] round_filter input=80 output=160
# I1214 04:54:05.871551 140532618450816 efficientnet_model.py:147] round_filter input=80 output=160
# I1214 04:54:05.871779 140532618450816 efficientnet_model.py:147] round_filter input=112 output=224
# I1214 04:54:06.849943 140532618450816 efficientnet_model.py:147] round_filter input=112 output=224
# I1214 04:54:06.850154 140532618450816 efficientnet_model.py:147] round_filter input=192 output=384
# I1214 04:54:08.366991 140532618450816 efficientnet_model.py:147] round_filter input=192 output=384
# I1214 04:54:08.367215 140532618450816 efficientnet_model.py:147] round_filter input=320 output=640
# I1214 04:54:08.785328 140532618450816 efficientnet_model.py:147] round_filter input=1280 output=2560
# I1214 04:54:08.822831 140532618450816 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 27.22s
# I1214 04:54:08.980377 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 27.22s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I1214 04:54:08.988659 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I1214 04:54:08.990727 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I1214 04:54:08.991355 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I1214 04:54:08.993468 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I1214 04:54:08.995416 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I1214 04:54:08.996022 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I1214 04:54:08.997204 140532618450816 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 34.769s
#
# OK (skipped=1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/training_demo/pre-trained-models
# Out:
# /content/drive/MyDrive/training_demo/pre-trained-models

# %%
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Out:
# --2021-12-14 04:54:27--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.125.128, 2607:f8b0:4001:c2f::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.125.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M  51.4MB/s    in 0.4s
#
# 2021-12-14 04:54:27 (51.4 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]

# %%
# !tar -xvf ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Out:
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %%
pwd
# Out:
# '/content/drive/My Drive/training_demo/pre-trained-models'

# %%
cd /content/drive/MyDrive/training_demo
# Out:
# /content/drive/MyDrive/training_demo

# %%
ls
# Out:
# annotations/                model_main_tf2.py
# exported_models/            models/
# exporter_main_v2.py         pre-trained-models/
# export_tflite_graph_tf2.py  ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/
# generate_tfrecord.py        ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz
# images/

# %%
# Create train data:
# !python generate_tfrecord.py -x /content/drive/MyDrive/training_demo/images/train -l /content/drive/MyDrive/training_demo/annotations/label_map.pbtxt -o /content/drive/MyDrive/training_demo/annotations/train.record

# Create test data:
# !python generate_tfrecord.py -x /content/drive/MyDrive/training_demo/images/test -l /content/drive/MyDrive/training_demo/annotations/label_map.pbtxt -o /content/drive/MyDrive/training_demo/annotations/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/training_demo/annotations/train.record
# Successfully created the TFRecord file: /content/drive/MyDrive/training_demo/annotations/test.record

# %%
pwd
# Out:
# '/content/drive/My Drive/training_demo'

# %%
ls
# Out:
# annotations/                images/
# exported_models/            model_main_tf2.py
# exporter_main_v2.py         models/
# export_tflite_graph_tf2.py  pre-trained-models/
# generate_tfrecord.py        ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/training_demo/models/my_ssd_resnet101_v1_fpn --pipeline_config_path=/content/drive/MyDrive/training_demo/models/my_ssd_resnet101_v1_fpn/pipeline.config
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I1214 05:25:25.742408 140199886231424 mirrored_strategy.py:376] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I1214 05:25:25.750148 140199886231424 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1214 05:25:25.750362 140199886231424 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W1214 05:25:25.786209 140199886231424 deprecation.py:347] From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/content/drive/MyDrive/training_demo/annotations/train.record']
# I1214 05:25:25.796069 140199886231424 dataset_builder.py:163] Reading unweighted datasets: ['/content/drive/MyDrive/training_demo/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['/content/drive/MyDrive/training_demo/annotations/train.record']
# I1214 05:25:25.796463 140199886231424 dataset_builder.py:80] Reading record datasets for input file: ['/content/drive/MyDrive/training_demo/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1214 05:25:25.796591 140199886231424 dataset_builder.py:81] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1214 05:25:25.796705 140199886231424 dataset_builder.py:88] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1214 05:25:25.799904 140199886231424 deprecation.py:347] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:237: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1214 05:25:25.825372 140199886231424 deprecation.py:347] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:237: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1214 05:25:34.754368 140199886231424 deprecation.py:347] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W1214 05:25:38.645518 140199886231424 deprecation.py:347] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:465: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1214 05:25:40.801743 140199886231424 deprecation.py:347] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:465: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:414: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1214 05:26:10.051765 140199886231424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1214 05:26:10.053093 140199886231424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1214 05:26:10.055661 140199886231424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1214 05:26:10.056962 140199886231424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1214 05:26:10.059680 140199886231424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1214 05:26:10.060869 140199886231424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1214 05:26:10.063587 140199886231424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1214 05:26:10.064709 140199886231424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1214 05:26:10.067246 140199886231424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1214 05:26:10.068401 140199886231424 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:620: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W1214 05:26:10.927180 140194993370880 deprecation.py:551] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:620: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 0.584s
# I1214 05:27:08.854863 140199886231424 model_lib_v2.py:707] Step 100 per-step time 0.584s
# INFO:tensorflow:{'Loss/classification_loss': 0.2174521,
#  'Loss/localization_loss': 0.2680532,
#  'Loss/regularization_loss': 0.1539772,
#  'Loss/total_loss': 0.6394825,
#  'learning_rate': 0.0319994}
# I1214 05:27:08.855306 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.2174521,
#  'Loss/localization_loss': 0.2680532,
#  'Loss/regularization_loss': 0.1539772,
#  'Loss/total_loss': 0.6394825,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.190s
# I1214 05:27:27.816080 140199886231424 model_lib_v2.py:707] Step 200 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.15217824,
#  'Loss/localization_loss': 0.15540096,
#  'Loss/regularization_loss': 0.15388991,
#  'Loss/total_loss': 0.4614691,
#  'learning_rate': 0.0373328}
# I1214 05:27:27.816560 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.15217824,
#  'Loss/localization_loss': 0.15540096,
#  'Loss/regularization_loss': 0.15388991,
#  'Loss/total_loss': 0.4614691,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.189s
# I1214 05:27:46.719471 140199886231424 model_lib_v2.py:707] Step 300 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.09925567,
#  'Loss/localization_loss': 0.108436,
#  'Loss/regularization_loss': 0.15369505,
#  'Loss/total_loss': 0.36138672,
#  'learning_rate': 0.0426662}
# I1214 05:27:46.719866 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.09925567,
#  'Loss/localization_loss': 0.108436,
#  'Loss/regularization_loss': 0.15369505,
#  'Loss/total_loss': 0.36138672,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.190s
# I1214 05:28:05.703853 140199886231424 model_lib_v2.py:707] Step 400 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.11841574,
#  'Loss/localization_loss': 0.07912442,
#  'Loss/regularization_loss': 0.15339543,
#  'Loss/total_loss': 0.35093558,
#  'learning_rate': 0.047999598}
# I1214 05:28:05.704238 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.11841574,
#  'Loss/localization_loss': 0.07912442,
#  'Loss/regularization_loss': 0.15339543,
#  'Loss/total_loss': 0.35093558,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.191s
# I1214 05:28:24.768913 140199886231424 model_lib_v2.py:707] Step 500 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.15590386,
#  'Loss/localization_loss': 0.09458818,
#  'Loss/regularization_loss': 0.15310279,
#  'Loss/total_loss': 0.40359482,
#  'learning_rate': 0.053333}
# I1214 05:28:24.769333 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.15590386,
#  'Loss/localization_loss': 0.09458818,
#  'Loss/regularization_loss': 0.15310279,
#  'Loss/total_loss': 0.40359482,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.191s
# I1214 05:28:43.840995 140199886231424 model_lib_v2.py:707] Step 600 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.08789787,
#  'Loss/localization_loss': 0.0697504,
#  'Loss/regularization_loss': 0.15271978,
#  'Loss/total_loss': 0.31036806,
#  'learning_rate': 0.0586664}
# I1214 05:28:43.841386 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.08789787,
#  'Loss/localization_loss': 0.0697504,
#  'Loss/regularization_loss': 0.15271978,
#  'Loss/total_loss': 0.31036806,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.191s
# I1214 05:29:02.926031 140199886231424 model_lib_v2.py:707] Step 700 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.081117995,
#  'Loss/localization_loss': 0.03501293,
#  'Loss/regularization_loss': 0.15236504,
#  'Loss/total_loss': 0.26849598,
#  'learning_rate': 0.0639998}
# I1214 05:29:02.926408 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.081117995,
#  'Loss/localization_loss': 0.03501293,
#  'Loss/regularization_loss': 0.15236504,
#  'Loss/total_loss': 0.26849598,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.190s
# I1214 05:29:21.962794 140199886231424 model_lib_v2.py:707] Step 800 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.07646206,
#  'Loss/localization_loss': 0.04433748,
#  'Loss/regularization_loss': 0.15191597,
#  'Loss/total_loss': 0.2727155,
#  'learning_rate': 0.069333196}
# I1214 05:29:21.963245 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.07646206,
#  'Loss/localization_loss': 0.04433748,
#  'Loss/regularization_loss': 0.15191597,
#  'Loss/total_loss': 0.2727155,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.190s
# I1214 05:29:41.002491 140199886231424 model_lib_v2.py:707] Step 900 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.09272911,
#  'Loss/localization_loss': 0.062598914,
#  'Loss/regularization_loss': 0.15145092,
#  'Loss/total_loss': 0.30677894,
#  'learning_rate': 0.074666604}
# I1214 05:29:41.002907 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.09272911,
#  'Loss/localization_loss': 0.062598914,
#  'Loss/regularization_loss': 0.15145092,
#  'Loss/total_loss': 0.30677894,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.190s
# I1214 05:30:00.030066 140199886231424 model_lib_v2.py:707] Step 1000 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.113123134,
#  'Loss/localization_loss': 0.048600573,
#  'Loss/regularization_loss': 0.15091243,
#  'Loss/total_loss': 0.31263614,
#  'learning_rate': 0.08}
# I1214 05:30:00.030569 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.113123134,
#  'Loss/localization_loss': 0.048600573,
#  'Loss/regularization_loss': 0.15091243,
#  'Loss/total_loss': 0.31263614,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.197s
# I1214 05:30:19.712621 140199886231424 model_lib_v2.py:707] Step 1100 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.094142914,
#  'Loss/localization_loss': 0.05954754,
#  'Loss/regularization_loss': 0.15036827,
#  'Loss/total_loss': 0.30405873,
#  'learning_rate': 0.07999657}
# I1214 05:30:19.713029 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.094142914,
#  'Loss/localization_loss': 0.05954754,
#  'Loss/regularization_loss': 0.15036827,
#  'Loss/total_loss': 0.30405873,
#  'learning_rate': 0.07999657}
# INFO:tensorflow:Step 1200 per-step time 0.190s
# I1214 05:30:38.757743 140199886231424 model_lib_v2.py:707] Step 1200 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.060489893,
#  'Loss/localization_loss': 0.030886201,
#  'Loss/regularization_loss': 0.1497961,
#  'Loss/total_loss': 0.2411722,
#  'learning_rate': 0.0799863}
# I1214 05:30:38.758117 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.060489893,
#  'Loss/localization_loss': 0.030886201,
#  'Loss/regularization_loss': 0.1497961,
#  'Loss/total_loss': 0.2411722,
#  'learning_rate': 0.0799863}
# INFO:tensorflow:Step 1300 per-step time 0.190s
# I1214 05:30:57.764416 140199886231424 model_lib_v2.py:707] Step 1300 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.12804231,
#  'Loss/localization_loss': 0.054561898,
#  'Loss/regularization_loss': 0.149215,
#  'Loss/total_loss': 0.3318192,
#  'learning_rate': 0.07996915}
# I1214 05:30:57.764874 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.12804231,
#  'Loss/localization_loss': 0.054561898,
#  'Loss/regularization_loss': 0.149215,
#  'Loss/total_loss': 0.3318192,
#  'learning_rate': 0.07996915}
# INFO:tensorflow:Step 1400 per-step time 0.190s
# I1214 05:31:16.781017 140199886231424 model_lib_v2.py:707] Step 1400 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.065473594,
#  'Loss/localization_loss': 0.039458983,
#  'Loss/regularization_loss': 0.14861767,
#  'Loss/total_loss': 0.25355023,
#  'learning_rate': 0.079945184}
# I1214 05:31:16.781440 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.065473594,
#  'Loss/localization_loss': 0.039458983,
#  'Loss/regularization_loss': 0.14861767,
#  'Loss/total_loss': 0.25355023,
#  'learning_rate': 0.079945184}
# INFO:tensorflow:Step 1500 per-step time 0.191s
# I1214 05:31:35.841660 140199886231424 model_lib_v2.py:707] Step 1500 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.09944409,
#  'Loss/localization_loss': 0.04623066,
#  'Loss/regularization_loss': 0.14793795,
#  'Loss/total_loss': 0.29361272,
#  'learning_rate': 0.07991436}
# I1214 05:31:35.842088 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.09944409,
#  'Loss/localization_loss': 0.04623066,
#  'Loss/regularization_loss': 0.14793795,
#  'Loss/total_loss': 0.29361272,
#  'learning_rate': 0.07991436}
# INFO:tensorflow:Step 1600 per-step time 0.188s
# I1214 05:31:54.671297 140199886231424 model_lib_v2.py:707] Step 1600 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.07965501,
#  'Loss/localization_loss': 0.05253346,
#  'Loss/regularization_loss': 0.14724495,
#  'Loss/total_loss': 0.27943343,
#  'learning_rate': 0.07987669}
# I1214 05:31:54.671673 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.07965501,
#  'Loss/localization_loss': 0.05253346,
#  'Loss/regularization_loss': 0.14724495,
#  'Loss/total_loss': 0.27943343,
#  'learning_rate': 0.07987669}
# INFO:tensorflow:Step 1700 per-step time 0.189s
# I1214 05:32:13.579231 140199886231424 model_lib_v2.py:707] Step 1700 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.08124497,
#  'Loss/localization_loss': 0.02644144,
#  'Loss/regularization_loss': 0.14656731,
#  'Loss/total_loss': 0.25425372,
#  'learning_rate': 0.079832196}
# I1214 05:32:13.579600 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.08124497,
#  'Loss/localization_loss': 0.02644144,
#  'Loss/regularization_loss': 0.14656731,
#  'Loss/total_loss': 0.25425372,
#  'learning_rate': 0.079832196}
# INFO:tensorflow:Step 1800 per-step time 0.189s
# I1214 05:32:32.528795 140199886231424 model_lib_v2.py:707] Step 1800 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.067938186,
#  'Loss/localization_loss': 0.028565723,
#  'Loss/regularization_loss': 0.14597313,
#  'Loss/total_loss': 0.24247704,
#  'learning_rate': 0.07978087}
# I1214 05:32:32.529198 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.067938186,
#  'Loss/localization_loss': 0.028565723,
#  'Loss/regularization_loss': 0.14597313,
#  'Loss/total_loss': 0.24247704,
#  'learning_rate': 0.07978087}
# INFO:tensorflow:Step 1900 per-step time 0.189s
# I1214 05:32:51.422656 140199886231424 model_lib_v2.py:707] Step 1900 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.07406379,
#  'Loss/localization_loss': 0.036752734,
#  'Loss/regularization_loss': 0.14526926,
#  'Loss/total_loss': 0.25608578,
#  'learning_rate': 0.07972274}
# I1214 05:32:51.423105 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.07406379,
#  'Loss/localization_loss': 0.036752734,
#  'Loss/regularization_loss': 0.14526926,
#  'Loss/total_loss': 0.25608578,
#  'learning_rate': 0.07972274}
# INFO:tensorflow:Step 2000 per-step time 0.191s
# I1214 05:33:10.525405 140199886231424 model_lib_v2.py:707] Step 2000 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.06735937,
#  'Loss/localization_loss': 0.03663809,
#  'Loss/regularization_loss': 0.14459446,
#  'Loss/total_loss': 0.24859193,
#  'learning_rate': 0.07965779}
# I1214 05:33:10.525761 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.06735937,
#  'Loss/localization_loss': 0.03663809,
#  'Loss/regularization_loss': 0.14459446,
#  'Loss/total_loss': 0.24859193,
#  'learning_rate': 0.07965779}
# INFO:tensorflow:Step 2100 per-step time 0.196s
# I1214 05:33:30.148977 140199886231424 model_lib_v2.py:707] Step 2100 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.045181163,
#  'Loss/localization_loss': 0.035725582,
#  'Loss/regularization_loss': 0.14389545,
#  'Loss/total_loss': 0.2248022,
#  'learning_rate': 0.07958606}
# I1214 05:33:30.149353 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.045181163,
#  'Loss/localization_loss': 0.035725582,
#  'Loss/regularization_loss': 0.14389545,
#  'Loss/total_loss': 0.2248022,
#  'learning_rate': 0.07958606}
# INFO:tensorflow:Step 2200 per-step time 0.189s
# I1214 05:33:49.095944 140199886231424 model_lib_v2.py:707] Step 2200 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.087619126,
#  'Loss/localization_loss': 0.034512695,
#  'Loss/regularization_loss': 0.14321122,
#  'Loss/total_loss': 0.26534304,
#  'learning_rate': 0.07950753}
# I1214 05:33:49.096556 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.087619126,
#  'Loss/localization_loss': 0.034512695,
#  'Loss/regularization_loss': 0.14321122,
#  'Loss/total_loss': 0.26534304,
#  'learning_rate': 0.07950753}
# INFO:tensorflow:Step 2300 per-step time 0.191s
# I1214 05:34:08.178587 140199886231424 model_lib_v2.py:707] Step 2300 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.07440935,
#  'Loss/localization_loss': 0.027543485,
#  'Loss/regularization_loss': 0.1425161,
#  'Loss/total_loss': 0.24446894,
#  'learning_rate': 0.07942224}
# I1214 05:34:08.179031 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.07440935,
#  'Loss/localization_loss': 0.027543485,
#  'Loss/regularization_loss': 0.1425161,
#  'Loss/total_loss': 0.24446894,
#  'learning_rate': 0.07942224}
# INFO:tensorflow:Step 2400 per-step time 0.188s
# I1214 05:34:27.004492 140199886231424 model_lib_v2.py:707] Step 2400 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.06958151,
#  'Loss/localization_loss': 0.033469863,
#  'Loss/regularization_loss': 0.14187735,
#  'Loss/total_loss': 0.24492872,
#  'learning_rate': 0.07933019}
# I1214 05:34:27.004983 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.06958151,
#  'Loss/localization_loss': 0.033469863,
#  'Loss/regularization_loss': 0.14187735,
#  'Loss/total_loss': 0.24492872,
#  'learning_rate': 0.07933019}
# INFO:tensorflow:Step 2500 per-step time 0.190s
# I1214 05:34:45.962389 140199886231424 model_lib_v2.py:707] Step 2500 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.06930618,
#  'Loss/localization_loss': 0.022846418,
#  'Loss/regularization_loss': 0.14119658,
#  'Loss/total_loss': 0.23334917,
#  'learning_rate': 0.07923141}
# I1214 05:34:45.962739 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.06930618,
#  'Loss/localization_loss': 0.022846418,
#  'Loss/regularization_loss': 0.14119658,
#  'Loss/total_loss': 0.23334917,
#  'learning_rate': 0.07923141}
# INFO:tensorflow:Step 2600 per-step time 0.190s
# I1214 05:35:04.961298 140199886231424 model_lib_v2.py:707] Step 2600 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.06486287,
#  'Loss/localization_loss': 0.034328133,
#  'Loss/regularization_loss': 0.1405025,
#  'Loss/total_loss': 0.2396935,
#  'learning_rate': 0.0791259}
# I1214 05:35:04.961742 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.06486287,
#  'Loss/localization_loss': 0.034328133,
#  'Loss/regularization_loss': 0.1405025,
#  'Loss/total_loss': 0.2396935,
#  'learning_rate': 0.0791259}
# INFO:tensorflow:Step 2700 per-step time 0.190s
# I1214 05:35:23.931507 140199886231424 model_lib_v2.py:707] Step 2700 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.06994015,
#  'Loss/localization_loss': 0.02175816,
#  'Loss/regularization_loss': 0.13993825,
#  'Loss/total_loss': 0.23163655,
#  'learning_rate': 0.07901369}
# I1214 05:35:23.931906 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.06994015,
#  'Loss/localization_loss': 0.02175816,
#  'Loss/regularization_loss': 0.13993825,
#  'Loss/total_loss': 0.23163655,
#  'learning_rate': 0.07901369}
# INFO:tensorflow:Step 2800 per-step time 0.190s
# I1214 05:35:42.905614 140199886231424 model_lib_v2.py:707] Step 2800 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.071520865,
#  'Loss/localization_loss': 0.023070663,
#  'Loss/regularization_loss': 0.13923523,
#  'Loss/total_loss': 0.23382676,
#  'learning_rate': 0.078894794}
# I1214 05:35:42.906001 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.071520865,
#  'Loss/localization_loss': 0.023070663,
#  'Loss/regularization_loss': 0.13923523,
#  'Loss/total_loss': 0.23382676,
#  'learning_rate': 0.078894794}
# INFO:tensorflow:Step 2900 per-step time 0.190s
# I1214 05:36:01.875002 140199886231424 model_lib_v2.py:707] Step 2900 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.049100287,
#  'Loss/localization_loss': 0.014036421,
#  'Loss/regularization_loss': 0.13852023,
#  'Loss/total_loss': 0.20165694,
#  'learning_rate': 0.07876924}
# I1214 05:36:01.875342 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.049100287,
#  'Loss/localization_loss': 0.014036421,
#  'Loss/regularization_loss': 0.13852023,
#  'Loss/total_loss': 0.20165694,
#  'learning_rate': 0.07876924}
# INFO:tensorflow:Step 3000 per-step time 0.191s
# I1214 05:36:20.941048 140199886231424 model_lib_v2.py:707] Step 3000 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.090834595,
#  'Loss/localization_loss': 0.034644682,
#  'Loss/regularization_loss': 0.13792649,
#  'Loss/total_loss': 0.26340577,
#  'learning_rate': 0.07863703}
# I1214 05:36:20.941445 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.090834595,
#  'Loss/localization_loss': 0.034644682,
#  'Loss/regularization_loss': 0.13792649,
#  'Loss/total_loss': 0.26340577,
#  'learning_rate': 0.07863703}
# INFO:tensorflow:Step 3100 per-step time 0.196s
# I1214 05:36:40.574905 140199886231424 model_lib_v2.py:707] Step 3100 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.057758357,
#  'Loss/localization_loss': 0.019905094,
#  'Loss/regularization_loss': 0.13733476,
#  'Loss/total_loss': 0.21499822,
#  'learning_rate': 0.07849821}
# I1214 05:36:40.575339 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.057758357,
#  'Loss/localization_loss': 0.019905094,
#  'Loss/regularization_loss': 0.13733476,
#  'Loss/total_loss': 0.21499822,
#  'learning_rate': 0.07849821}
# INFO:tensorflow:Step 3200 per-step time 0.191s
# I1214 05:36:59.691604 140199886231424 model_lib_v2.py:707] Step 3200 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.04146136,
#  'Loss/localization_loss': 0.015375946,
#  'Loss/regularization_loss': 0.13662508,
#  'Loss/total_loss': 0.19346239,
#  'learning_rate': 0.07835279}
# I1214 05:36:59.691965 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.04146136,
#  'Loss/localization_loss': 0.015375946,
#  'Loss/regularization_loss': 0.13662508,
#  'Loss/total_loss': 0.19346239,
#  'learning_rate': 0.07835279}
# INFO:tensorflow:Step 3300 per-step time 0.191s
# I1214 05:37:18.797941 140199886231424 model_lib_v2.py:707] Step 3300 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.04186433,
#  'Loss/localization_loss': 0.018481184,
#  'Loss/regularization_loss': 0.13593175,
#  'Loss/total_loss': 0.19627726,
#  'learning_rate': 0.078200795}
# I1214 05:37:18.798331 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.04186433,
#  'Loss/localization_loss': 0.018481184,
#  'Loss/regularization_loss': 0.13593175,
#  'Loss/total_loss': 0.19627726,
#  'learning_rate': 0.078200795}
# INFO:tensorflow:Step 3400 per-step time 0.191s
# I1214 05:37:37.924059 140199886231424 model_lib_v2.py:707] Step 3400 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.06615783,
#  'Loss/localization_loss': 0.020077536,
#  'Loss/regularization_loss': 0.13529369,
#  'Loss/total_loss': 0.22152907,
#  'learning_rate': 0.078042254}
# I1214 05:37:37.924483 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.06615783,
#  'Loss/localization_loss': 0.020077536,
#  'Loss/regularization_loss': 0.13529369,
#  'Loss/total_loss': 0.22152907,
#  'learning_rate': 0.078042254}
# INFO:tensorflow:Step 3500 per-step time 0.189s
# I1214 05:37:56.868507 140199886231424 model_lib_v2.py:707] Step 3500 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.05654867,
#  'Loss/localization_loss': 0.011411893,
#  'Loss/regularization_loss': 0.13468638,
#  'Loss/total_loss': 0.20264694,
#  'learning_rate': 0.07787721}
# I1214 05:37:56.868947 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.05654867,
#  'Loss/localization_loss': 0.011411893,
#  'Loss/regularization_loss': 0.13468638,
#  'Loss/total_loss': 0.20264694,
#  'learning_rate': 0.07787721}
# INFO:tensorflow:Step 3600 per-step time 0.191s
# I1214 05:38:15.949847 140199886231424 model_lib_v2.py:707] Step 3600 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.058261976,
#  'Loss/localization_loss': 0.018895285,
#  'Loss/regularization_loss': 0.13403688,
#  'Loss/total_loss': 0.21119414,
#  'learning_rate': 0.07770566}
# I1214 05:38:15.950268 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.058261976,
#  'Loss/localization_loss': 0.018895285,
#  'Loss/regularization_loss': 0.13403688,
#  'Loss/total_loss': 0.21119414,
#  'learning_rate': 0.07770566}
# INFO:tensorflow:Step 3700 per-step time 0.188s
# I1214 05:38:34.757391 140199886231424 model_lib_v2.py:707] Step 3700 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.043128487,
#  'Loss/localization_loss': 0.016432805,
#  'Loss/regularization_loss': 0.13333243,
#  'Loss/total_loss': 0.19289371,
#  'learning_rate': 0.07752766}
# I1214 05:38:34.757754 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.043128487,
#  'Loss/localization_loss': 0.016432805,
#  'Loss/regularization_loss': 0.13333243,
#  'Loss/total_loss': 0.19289371,
#  'learning_rate': 0.07752766}
# INFO:tensorflow:Step 3800 per-step time 0.191s
# I1214 05:38:53.869864 140199886231424 model_lib_v2.py:707] Step 3800 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.048430767,
#  'Loss/localization_loss': 0.029991968,
#  'Loss/regularization_loss': 0.13266554,
#  'Loss/total_loss': 0.21108827,
#  'learning_rate': 0.07734321}
# I1214 05:38:53.870285 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.048430767,
#  'Loss/localization_loss': 0.029991968,
#  'Loss/regularization_loss': 0.13266554,
#  'Loss/total_loss': 0.21108827,
#  'learning_rate': 0.07734321}
# INFO:tensorflow:Step 3900 per-step time 0.190s
# I1214 05:39:12.895705 140199886231424 model_lib_v2.py:707] Step 3900 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.054581076,
#  'Loss/localization_loss': 0.030758612,
#  'Loss/regularization_loss': 0.13203248,
#  'Loss/total_loss': 0.21737218,
#  'learning_rate': 0.07715238}
# I1214 05:39:12.896108 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.054581076,
#  'Loss/localization_loss': 0.030758612,
#  'Loss/regularization_loss': 0.13203248,
#  'Loss/total_loss': 0.21737218,
#  'learning_rate': 0.07715238}
# INFO:tensorflow:Step 4000 per-step time 0.191s
# I1214 05:39:32.014183 140199886231424 model_lib_v2.py:707] Step 4000 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.06691937,
#  'Loss/localization_loss': 0.016163994,
#  'Loss/regularization_loss': 0.13138951,
#  'Loss/total_loss': 0.21447287,
#  'learning_rate': 0.076955184}
# I1214 05:39:32.014536 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.06691937,
#  'Loss/localization_loss': 0.016163994,
#  'Loss/regularization_loss': 0.13138951,
#  'Loss/total_loss': 0.21447287,
#  'learning_rate': 0.076955184}
# INFO:tensorflow:Step 4100 per-step time 0.197s
# I1214 05:39:51.739971 140199886231424 model_lib_v2.py:707] Step 4100 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.102226265,
#  'Loss/localization_loss': 0.033827174,
#  'Loss/regularization_loss': 0.13072239,
#  'Loss/total_loss': 0.26677585,
#  'learning_rate': 0.07675164}
# I1214 05:39:51.740339 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.102226265,
#  'Loss/localization_loss': 0.033827174,
#  'Loss/regularization_loss': 0.13072239,
#  'Loss/total_loss': 0.26677585,
#  'learning_rate': 0.07675164}
# INFO:tensorflow:Step 4200 per-step time 0.189s
# I1214 05:40:10.650316 140199886231424 model_lib_v2.py:707] Step 4200 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.08030178,
#  'Loss/localization_loss': 0.014634111,
#  'Loss/regularization_loss': 0.13017277,
#  'Loss/total_loss': 0.22510865,
#  'learning_rate': 0.07654182}
# I1214 05:40:10.650702 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.08030178,
#  'Loss/localization_loss': 0.014634111,
#  'Loss/regularization_loss': 0.13017277,
#  'Loss/total_loss': 0.22510865,
#  'learning_rate': 0.07654182}
# INFO:tensorflow:Step 4300 per-step time 0.190s
# I1214 05:40:29.696918 140199886231424 model_lib_v2.py:707] Step 4300 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.063285284,
#  'Loss/localization_loss': 0.024717141,
#  'Loss/regularization_loss': 0.12955149,
#  'Loss/total_loss': 0.21755391,
#  'learning_rate': 0.07632572}
# I1214 05:40:29.697283 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.063285284,
#  'Loss/localization_loss': 0.024717141,
#  'Loss/regularization_loss': 0.12955149,
#  'Loss/total_loss': 0.21755391,
#  'learning_rate': 0.07632572}
# INFO:tensorflow:Step 4400 per-step time 0.191s
# I1214 05:40:48.803332 140199886231424 model_lib_v2.py:707] Step 4400 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.054227117,
#  'Loss/localization_loss': 0.015657326,
#  'Loss/regularization_loss': 0.12892526,
#  'Loss/total_loss': 0.19880971,
#  'learning_rate': 0.07610341}
# I1214 05:40:48.803739 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.054227117,
#  'Loss/localization_loss': 0.015657326,
#  'Loss/regularization_loss': 0.12892526,
#  'Loss/total_loss': 0.19880971,
#  'learning_rate': 0.07610341}
# INFO:tensorflow:Step 4500 per-step time 0.190s
# I1214 05:41:07.814933 140199886231424 model_lib_v2.py:707] Step 4500 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.062080648,
#  'Loss/localization_loss': 0.021515986,
#  'Loss/regularization_loss': 0.12827504,
#  'Loss/total_loss': 0.21187167,
#  'learning_rate': 0.07587491}
# I1214 05:41:07.815303 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.062080648,
#  'Loss/localization_loss': 0.021515986,
#  'Loss/regularization_loss': 0.12827504,
#  'Loss/total_loss': 0.21187167,
#  'learning_rate': 0.07587491}
# INFO:tensorflow:Step 4600 per-step time 0.191s
# I1214 05:41:26.905886 140199886231424 model_lib_v2.py:707] Step 4600 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.037005477,
#  'Loss/localization_loss': 0.013981195,
#  'Loss/regularization_loss': 0.12764156,
#  'Loss/total_loss': 0.17862824,
#  'learning_rate': 0.07564025}
# I1214 05:41:26.906310 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.037005477,
#  'Loss/localization_loss': 0.013981195,
#  'Loss/regularization_loss': 0.12764156,
#  'Loss/total_loss': 0.17862824,
#  'learning_rate': 0.07564025}
# INFO:tensorflow:Step 4700 per-step time 0.191s
# I1214 05:41:45.953917 140199886231424 model_lib_v2.py:707] Step 4700 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.07629233,
#  'Loss/localization_loss': 0.016606366,
#  'Loss/regularization_loss': 0.12702812,
#  'Loss/total_loss': 0.21992682,
#  'learning_rate': 0.0753995}
# I1214 05:41:45.954298 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.07629233,
#  'Loss/localization_loss': 0.016606366,
#  'Loss/regularization_loss': 0.12702812,
#  'Loss/total_loss': 0.21992682,
#  'learning_rate': 0.0753995}
# INFO:tensorflow:Step 4800 per-step time 0.190s
# I1214 05:42:04.977200 140199886231424 model_lib_v2.py:707] Step 4800 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.04459775,
#  'Loss/localization_loss': 0.01577672,
#  'Loss/regularization_loss': 0.12644616,
#  'Loss/total_loss': 0.18682063,
#  'learning_rate': 0.07515268}
# I1214 05:42:04.977602 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.04459775,
#  'Loss/localization_loss': 0.01577672,
#  'Loss/regularization_loss': 0.12644616,
#  'Loss/total_loss': 0.18682063,
#  'learning_rate': 0.07515268}
# INFO:tensorflow:Step 4900 per-step time 0.189s
# I1214 05:42:23.862135 140199886231424 model_lib_v2.py:707] Step 4900 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.044071987,
#  'Loss/localization_loss': 0.012271227,
#  'Loss/regularization_loss': 0.12580694,
#  'Loss/total_loss': 0.18215016,
#  'learning_rate': 0.07489984}
# I1214 05:42:23.862461 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.044071987,
#  'Loss/localization_loss': 0.012271227,
#  'Loss/regularization_loss': 0.12580694,
#  'Loss/total_loss': 0.18215016,
#  'learning_rate': 0.07489984}
# INFO:tensorflow:Step 5000 per-step time 0.189s
# I1214 05:42:42.795069 140199886231424 model_lib_v2.py:707] Step 5000 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.034677282,
#  'Loss/localization_loss': 0.011423953,
#  'Loss/regularization_loss': 0.12518433,
#  'Loss/total_loss': 0.17128557,
#  'learning_rate': 0.07464102}
# I1214 05:42:42.795419 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.034677282,
#  'Loss/localization_loss': 0.011423953,
#  'Loss/regularization_loss': 0.12518433,
#  'Loss/total_loss': 0.17128557,
#  'learning_rate': 0.07464102}
# INFO:tensorflow:Step 5100 per-step time 0.198s
# I1214 05:43:02.635116 140199886231424 model_lib_v2.py:707] Step 5100 per-step time 0.198s
# INFO:tensorflow:{'Loss/classification_loss': 0.046575256,
#  'Loss/localization_loss': 0.011352805,
#  'Loss/regularization_loss': 0.12457613,
#  'Loss/total_loss': 0.18250419,
#  'learning_rate': 0.074376255}
# I1214 05:43:02.635518 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.046575256,
#  'Loss/localization_loss': 0.011352805,
#  'Loss/regularization_loss': 0.12457613,
#  'Loss/total_loss': 0.18250419,
#  'learning_rate': 0.074376255}
# INFO:tensorflow:Step 5200 per-step time 0.191s
# I1214 05:43:21.766599 140199886231424 model_lib_v2.py:707] Step 5200 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.05402683,
#  'Loss/localization_loss': 0.023901848,
#  'Loss/regularization_loss': 0.12395927,
#  'Loss/total_loss': 0.20188795,
#  'learning_rate': 0.074105605}
# I1214 05:43:21.767075 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.05402683,
#  'Loss/localization_loss': 0.023901848,
#  'Loss/regularization_loss': 0.12395927,
#  'Loss/total_loss': 0.20188795,
#  'learning_rate': 0.074105605}
# INFO:tensorflow:Step 5300 per-step time 0.192s
# I1214 05:43:40.923438 140199886231424 model_lib_v2.py:707] Step 5300 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.057414263,
#  'Loss/localization_loss': 0.011365555,
#  'Loss/regularization_loss': 0.123365775,
#  'Loss/total_loss': 0.19214559,
#  'learning_rate': 0.07382911}
# I1214 05:43:40.923789 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.057414263,
#  'Loss/localization_loss': 0.011365555,
#  'Loss/regularization_loss': 0.123365775,
#  'Loss/total_loss': 0.19214559,
#  'learning_rate': 0.07382911}
# INFO:tensorflow:Step 5400 per-step time 0.191s
# I1214 05:44:00.028615 140199886231424 model_lib_v2.py:707] Step 5400 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.05114509,
#  'Loss/localization_loss': 0.007933904,
#  'Loss/regularization_loss': 0.122774884,
#  'Loss/total_loss': 0.18185388,
#  'learning_rate': 0.07354682}
# I1214 05:44:00.029033 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.05114509,
#  'Loss/localization_loss': 0.007933904,
#  'Loss/regularization_loss': 0.122774884,
#  'Loss/total_loss': 0.18185388,
#  'learning_rate': 0.07354682}
# INFO:tensorflow:Step 5500 per-step time 0.191s
# I1214 05:44:19.142770 140199886231424 model_lib_v2.py:707] Step 5500 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.042464573,
#  'Loss/localization_loss': 0.012737919,
#  'Loss/regularization_loss': 0.12219672,
#  'Loss/total_loss': 0.17739922,
#  'learning_rate': 0.07325879}
# I1214 05:44:19.143358 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.042464573,
#  'Loss/localization_loss': 0.012737919,
#  'Loss/regularization_loss': 0.12219672,
#  'Loss/total_loss': 0.17739922,
#  'learning_rate': 0.07325879}
# INFO:tensorflow:Step 5600 per-step time 0.191s
# I1214 05:44:38.213242 140199886231424 model_lib_v2.py:707] Step 5600 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.035514534,
#  'Loss/localization_loss': 0.011715296,
#  'Loss/regularization_loss': 0.12169051,
#  'Loss/total_loss': 0.16892034,
#  'learning_rate': 0.07296505}
# I1214 05:44:38.213609 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.035514534,
#  'Loss/localization_loss': 0.011715296,
#  'Loss/regularization_loss': 0.12169051,
#  'Loss/total_loss': 0.16892034,
#  'learning_rate': 0.07296505}
# INFO:tensorflow:Step 5700 per-step time 0.191s
# I1214 05:44:57.362136 140199886231424 model_lib_v2.py:707] Step 5700 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.031021252,
#  'Loss/localization_loss': 0.012374538,
#  'Loss/regularization_loss': 0.12111896,
#  'Loss/total_loss': 0.16451475,
#  'learning_rate': 0.07266566}
# I1214 05:44:57.362552 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.031021252,
#  'Loss/localization_loss': 0.012374538,
#  'Loss/regularization_loss': 0.12111896,
#  'Loss/total_loss': 0.16451475,
#  'learning_rate': 0.07266566}
# INFO:tensorflow:Step 5800 per-step time 0.190s
# I1214 05:45:16.354973 140199886231424 model_lib_v2.py:707] Step 5800 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.06722287,
#  'Loss/localization_loss': 0.015554962,
#  'Loss/regularization_loss': 0.12056585,
#  'Loss/total_loss': 0.20334369,
#  'learning_rate': 0.07236068}
# I1214 05:45:16.355523 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.06722287,
#  'Loss/localization_loss': 0.015554962,
#  'Loss/regularization_loss': 0.12056585,
#  'Loss/total_loss': 0.20334369,
#  'learning_rate': 0.07236068}
# INFO:tensorflow:Step 5900 per-step time 0.190s
# I1214 05:45:35.383190 140199886231424 model_lib_v2.py:707] Step 5900 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.06727056,
#  'Loss/localization_loss': 0.013139756,
#  'Loss/regularization_loss': 0.120075814,
#  'Loss/total_loss': 0.20048612,
#  'learning_rate': 0.07205015}
# I1214 05:45:35.383557 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.06727056,
#  'Loss/localization_loss': 0.013139756,
#  'Loss/regularization_loss': 0.120075814,
#  'Loss/total_loss': 0.20048612,
#  'learning_rate': 0.07205015}
# INFO:tensorflow:Step 6000 per-step time 0.190s
# I1214 05:45:54.364061 140199886231424 model_lib_v2.py:707] Step 6000 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.049492396,
#  'Loss/localization_loss': 0.012443415,
#  'Loss/regularization_loss': 0.119589046,
#  'Loss/total_loss': 0.18152486,
#  'learning_rate': 0.07173413}
# I1214 05:45:54.364420 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.049492396,
#  'Loss/localization_loss': 0.012443415,
#  'Loss/regularization_loss': 0.119589046,
#  'Loss/total_loss': 0.18152486,
#  'learning_rate': 0.07173413}
# INFO:tensorflow:Step 6100 per-step time 0.197s
# I1214 05:46:14.105975 140199886231424 model_lib_v2.py:707] Step 6100 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.037277702,
#  'Loss/localization_loss': 0.015227675,
#  'Loss/regularization_loss': 0.119157225,
#  'Loss/total_loss': 0.1716626,
#  'learning_rate': 0.071412675}
# I1214 05:46:14.106327 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.037277702,
#  'Loss/localization_loss': 0.015227675,
#  'Loss/regularization_loss': 0.119157225,
#  'Loss/total_loss': 0.1716626,
#  'learning_rate': 0.071412675}
# INFO:tensorflow:Step 6200 per-step time 0.190s
# I1214 05:46:33.152304 140199886231424 model_lib_v2.py:707] Step 6200 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.049730197,
#  'Loss/localization_loss': 0.018416625,
#  'Loss/regularization_loss': 0.11862187,
#  'Loss/total_loss': 0.1867687,
#  'learning_rate': 0.07108584}
# I1214 05:46:33.152770 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.049730197,
#  'Loss/localization_loss': 0.018416625,
#  'Loss/regularization_loss': 0.11862187,
#  'Loss/total_loss': 0.1867687,
#  'learning_rate': 0.07108584}
# INFO:tensorflow:Step 6300 per-step time 0.189s
# I1214 05:46:52.093082 140199886231424 model_lib_v2.py:707] Step 6300 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.050653026,
#  'Loss/localization_loss': 0.01583792,
#  'Loss/regularization_loss': 0.1180493,
#  'Loss/total_loss': 0.18454024,
#  'learning_rate': 0.07075367}
# I1214 05:46:52.093509 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.050653026,
#  'Loss/localization_loss': 0.01583792,
#  'Loss/regularization_loss': 0.1180493,
#  'Loss/total_loss': 0.18454024,
#  'learning_rate': 0.07075367}
# INFO:tensorflow:Step 6400 per-step time 0.190s
# I1214 05:47:11.100018 140199886231424 model_lib_v2.py:707] Step 6400 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.041894823,
#  'Loss/localization_loss': 0.014224391,
#  'Loss/regularization_loss': 0.1174999,
#  'Loss/total_loss': 0.17361912,
#  'learning_rate': 0.07041624}
# I1214 05:47:11.100445 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.041894823,
#  'Loss/localization_loss': 0.014224391,
#  'Loss/regularization_loss': 0.1174999,
#  'Loss/total_loss': 0.17361912,
#  'learning_rate': 0.07041624}
# INFO:tensorflow:Step 6500 per-step time 0.188s
# I1214 05:47:29.923077 140199886231424 model_lib_v2.py:707] Step 6500 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.034405943,
#  'Loss/localization_loss': 0.010295901,
#  'Loss/regularization_loss': 0.11696302,
#  'Loss/total_loss': 0.16166487,
#  'learning_rate': 0.0700736}
# I1214 05:47:29.923553 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.034405943,
#  'Loss/localization_loss': 0.010295901,
#  'Loss/regularization_loss': 0.11696302,
#  'Loss/total_loss': 0.16166487,
#  'learning_rate': 0.0700736}
# INFO:tensorflow:Step 6600 per-step time 0.190s
# I1214 05:47:48.942430 140199886231424 model_lib_v2.py:707] Step 6600 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.030387858,
#  'Loss/localization_loss': 0.008940318,
#  'Loss/regularization_loss': 0.11640583,
#  'Loss/total_loss': 0.155734,
#  'learning_rate': 0.06972579}
# ...
#  'learning_rate': 0.002472348}
# INFO:tensorflow:Step 22400 per-step time 0.187s
# I1214 06:37:48.936908 140199886231424 model_lib_v2.py:707] Step 22400 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.014531681,
#  'Loss/localization_loss': 0.0060666497,
#  'Loss/regularization_loss': 0.081342466,
#  'Loss/total_loss': 0.101940796,
#  'learning_rate': 0.0022943376}
# I1214 06:37:48.937285 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.014531681,
#  'Loss/localization_loss': 0.0060666497,
#  'Loss/regularization_loss': 0.081342466,
#  'Loss/total_loss': 0.101940796,
#  'learning_rate': 0.0022943376}
# INFO:tensorflow:Step 22500 per-step time 0.188s
# I1214 06:38:07.692411 140199886231424 model_lib_v2.py:707] Step 22500 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.031494346,
#  'Loss/localization_loss': 0.0027765608,
#  'Loss/regularization_loss': 0.08132805,
#  'Loss/total_loss': 0.115598954,
#  'learning_rate': 0.002122793}
# I1214 06:38:07.692777 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.031494346,
#  'Loss/localization_loss': 0.0027765608,
#  'Loss/regularization_loss': 0.08132805,
#  'Loss/total_loss': 0.115598954,
#  'learning_rate': 0.002122793}
# INFO:tensorflow:Step 22600 per-step time 0.187s
# I1214 06:38:26.395588 140199886231424 model_lib_v2.py:707] Step 22600 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.01319547,
#  'Loss/localization_loss': 0.0022147433,
#  'Loss/regularization_loss': 0.08131471,
#  'Loss/total_loss': 0.09672493,
#  'learning_rate': 0.001957736}
# I1214 06:38:26.396027 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.01319547,
#  'Loss/localization_loss': 0.0022147433,
#  'Loss/regularization_loss': 0.08131471,
#  'Loss/total_loss': 0.09672493,
#  'learning_rate': 0.001957736}
# INFO:tensorflow:Step 22700 per-step time 0.188s
# I1214 06:38:45.187305 140199886231424 model_lib_v2.py:707] Step 22700 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.0119005935,
#  'Loss/localization_loss': 0.0019719377,
#  'Loss/regularization_loss': 0.08130249,
#  'Loss/total_loss': 0.09517502,
#  'learning_rate': 0.0017991995}
# I1214 06:38:45.187663 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.0119005935,
#  'Loss/localization_loss': 0.0019719377,
#  'Loss/regularization_loss': 0.08130249,
#  'Loss/total_loss': 0.09517502,
#  'learning_rate': 0.0017991995}
# INFO:tensorflow:Step 22800 per-step time 0.187s
# I1214 06:39:03.853661 140199886231424 model_lib_v2.py:707] Step 22800 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.019459777,
#  'Loss/localization_loss': 0.0024682425,
#  'Loss/regularization_loss': 0.081291266,
#  'Loss/total_loss': 0.103219286,
#  'learning_rate': 0.0016472101}
# I1214 06:39:03.854122 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.019459777,
#  'Loss/localization_loss': 0.0024682425,
#  'Loss/regularization_loss': 0.081291266,
#  'Loss/total_loss': 0.103219286,
#  'learning_rate': 0.0016472101}
# INFO:tensorflow:Step 22900 per-step time 0.189s
# I1214 06:39:22.712220 140199886231424 model_lib_v2.py:707] Step 22900 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.019569658,
#  'Loss/localization_loss': 0.0018539053,
#  'Loss/regularization_loss': 0.08128099,
#  'Loss/total_loss': 0.102704555,
#  'learning_rate': 0.0015017891}
# I1214 06:39:22.712773 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.019569658,
#  'Loss/localization_loss': 0.0018539053,
#  'Loss/regularization_loss': 0.08128099,
#  'Loss/total_loss': 0.102704555,
#  'learning_rate': 0.0015017891}
# INFO:tensorflow:Step 23000 per-step time 0.188s
# I1214 06:39:41.511909 140199886231424 model_lib_v2.py:707] Step 23000 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.018342918,
#  'Loss/localization_loss': 0.0018380021,
#  'Loss/regularization_loss': 0.08127162,
#  'Loss/total_loss': 0.10145254,
#  'learning_rate': 0.0013629651}
# I1214 06:39:41.512291 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.018342918,
#  'Loss/localization_loss': 0.0018380021,
#  'Loss/regularization_loss': 0.08127162,
#  'Loss/total_loss': 0.10145254,
#  'learning_rate': 0.0013629651}
# INFO:tensorflow:Step 23100 per-step time 0.196s
# I1214 06:40:01.145000 140199886231424 model_lib_v2.py:707] Step 23100 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.01958484,
#  'Loss/localization_loss': 0.0032843603,
#  'Loss/regularization_loss': 0.0812631,
#  'Loss/total_loss': 0.1041323,
#  'learning_rate': 0.0012307595}
# I1214 06:40:01.145476 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.01958484,
#  'Loss/localization_loss': 0.0032843603,
#  'Loss/regularization_loss': 0.0812631,
#  'Loss/total_loss': 0.1041323,
#  'learning_rate': 0.0012307595}
# INFO:tensorflow:Step 23200 per-step time 0.189s
# I1214 06:40:19.996818 140199886231424 model_lib_v2.py:707] Step 23200 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.010267506,
#  'Loss/localization_loss': 0.0015861135,
#  'Loss/regularization_loss': 0.08125545,
#  'Loss/total_loss': 0.09310907,
#  'learning_rate': 0.0011052036}
# I1214 06:40:19.997239 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.010267506,
#  'Loss/localization_loss': 0.0015861135,
#  'Loss/regularization_loss': 0.08125545,
#  'Loss/total_loss': 0.09310907,
#  'learning_rate': 0.0011052036}
# INFO:tensorflow:Step 23300 per-step time 0.189s
# I1214 06:40:38.879867 140199886231424 model_lib_v2.py:707] Step 23300 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.031002065,
#  'Loss/localization_loss': 0.0024004881,
#  'Loss/regularization_loss': 0.08124859,
#  'Loss/total_loss': 0.11465114,
#  'learning_rate': 0.0009863067}
# I1214 06:40:38.880255 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.031002065,
#  'Loss/localization_loss': 0.0024004881,
#  'Loss/regularization_loss': 0.08124859,
#  'Loss/total_loss': 0.11465114,
#  'learning_rate': 0.0009863067}
# INFO:tensorflow:Step 23400 per-step time 0.189s
# I1214 06:40:57.767364 140199886231424 model_lib_v2.py:707] Step 23400 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.01856456,
#  'Loss/localization_loss': 0.0018053378,
#  'Loss/regularization_loss': 0.081242494,
#  'Loss/total_loss': 0.10161239,
#  'learning_rate': 0.00087409496}
# I1214 06:40:57.767805 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.01856456,
#  'Loss/localization_loss': 0.0018053378,
#  'Loss/regularization_loss': 0.081242494,
#  'Loss/total_loss': 0.10161239,
#  'learning_rate': 0.00087409496}
# INFO:tensorflow:Step 23500 per-step time 0.189s
# I1214 06:41:16.704277 140199886231424 model_lib_v2.py:707] Step 23500 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.016989237,
#  'Loss/localization_loss': 0.0050804415,
#  'Loss/regularization_loss': 0.08123709,
#  'Loss/total_loss': 0.10330677,
#  'learning_rate': 0.0007685876}
# I1214 06:41:16.704645 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.016989237,
#  'Loss/localization_loss': 0.0050804415,
#  'Loss/regularization_loss': 0.08123709,
#  'Loss/total_loss': 0.10330677,
#  'learning_rate': 0.0007685876}
# INFO:tensorflow:Step 23600 per-step time 0.188s
# I1214 06:41:35.508465 140199886231424 model_lib_v2.py:707] Step 23600 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.022149961,
#  'Loss/localization_loss': 0.0020012492,
#  'Loss/regularization_loss': 0.08123236,
#  'Loss/total_loss': 0.105383575,
#  'learning_rate': 0.0006698036}
# I1214 06:41:35.508851 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.022149961,
#  'Loss/localization_loss': 0.0020012492,
#  'Loss/regularization_loss': 0.08123236,
#  'Loss/total_loss': 0.105383575,
#  'learning_rate': 0.0006698036}
# INFO:tensorflow:Step 23700 per-step time 0.187s
# I1214 06:41:54.190251 140199886231424 model_lib_v2.py:707] Step 23700 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.014147156,
#  'Loss/localization_loss': 0.0018411102,
#  'Loss/regularization_loss': 0.08122824,
#  'Loss/total_loss': 0.09721651,
#  'learning_rate': 0.00057775737}
# I1214 06:41:54.190652 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.014147156,
#  'Loss/localization_loss': 0.0018411102,
#  'Loss/regularization_loss': 0.08122824,
#  'Loss/total_loss': 0.09721651,
#  'learning_rate': 0.00057775737}
# INFO:tensorflow:Step 23800 per-step time 0.188s
# I1214 06:42:12.975285 140199886231424 model_lib_v2.py:707] Step 23800 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.019302867,
#  'Loss/localization_loss': 0.0051239682,
#  'Loss/regularization_loss': 0.08122471,
#  'Loss/total_loss': 0.10565154,
#  'learning_rate': 0.0004924655}
# I1214 06:42:12.975644 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.019302867,
#  'Loss/localization_loss': 0.0051239682,
#  'Loss/regularization_loss': 0.08122471,
#  'Loss/total_loss': 0.10565154,
#  'learning_rate': 0.0004924655}
# INFO:tensorflow:Step 23900 per-step time 0.188s
# I1214 06:42:31.773893 140199886231424 model_lib_v2.py:707] Step 23900 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.013390537,
#  'Loss/localization_loss': 0.002785242,
#  'Loss/regularization_loss': 0.08122172,
#  'Loss/total_loss': 0.0973975,
#  'learning_rate': 0.00041394233}
# I1214 06:42:31.774333 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.013390537,
#  'Loss/localization_loss': 0.002785242,
#  'Loss/regularization_loss': 0.08122172,
#  'Loss/total_loss': 0.0973975,
#  'learning_rate': 0.00041394233}
# INFO:tensorflow:Step 24000 per-step time 0.188s
# I1214 06:42:50.596887 140199886231424 model_lib_v2.py:707] Step 24000 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.025107538,
#  'Loss/localization_loss': 0.0035905056,
#  'Loss/regularization_loss': 0.081219226,
#  'Loss/total_loss': 0.10991727,
#  'learning_rate': 0.00034220456}
# I1214 06:42:50.597301 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.025107538,
#  'Loss/localization_loss': 0.0035905056,
#  'Loss/regularization_loss': 0.081219226,
#  'Loss/total_loss': 0.10991727,
#  'learning_rate': 0.00034220456}
# INFO:tensorflow:Step 24100 per-step time 0.195s
# I1214 06:43:10.103025 140199886231424 model_lib_v2.py:707] Step 24100 per-step time 0.195s
# INFO:tensorflow:{'Loss/classification_loss': 0.015519579,
#  'Loss/localization_loss': 0.001562062,
#  'Loss/regularization_loss': 0.081217185,
#  'Loss/total_loss': 0.098298825,
#  'learning_rate': 0.00027726172}
# I1214 06:43:10.103422 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.015519579,
#  'Loss/localization_loss': 0.001562062,
#  'Loss/regularization_loss': 0.081217185,
#  'Loss/total_loss': 0.098298825,
#  'learning_rate': 0.00027726172}
# INFO:tensorflow:Step 24200 per-step time 0.188s
# I1214 06:43:28.883332 140199886231424 model_lib_v2.py:707] Step 24200 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.019973285,
#  'Loss/localization_loss': 0.002691375,
#  'Loss/regularization_loss': 0.08121554,
#  'Loss/total_loss': 0.1038802,
#  'learning_rate': 0.00021912337}
# I1214 06:43:28.883743 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.019973285,
#  'Loss/localization_loss': 0.002691375,
#  'Loss/regularization_loss': 0.08121554,
#  'Loss/total_loss': 0.1038802,
#  'learning_rate': 0.00021912337}
# INFO:tensorflow:Step 24300 per-step time 0.188s
# I1214 06:43:47.633884 140199886231424 model_lib_v2.py:707] Step 24300 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.022359027,
#  'Loss/localization_loss': 0.0026276472,
#  'Loss/regularization_loss': 0.08121424,
#  'Loss/total_loss': 0.10620092,
#  'learning_rate': 0.00016780138}
# I1214 06:43:47.634280 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.022359027,
#  'Loss/localization_loss': 0.0026276472,
#  'Loss/regularization_loss': 0.08121424,
#  'Loss/total_loss': 0.10620092,
#  'learning_rate': 0.00016780138}
# INFO:tensorflow:Step 24400 per-step time 0.191s
# I1214 06:44:06.697552 140199886231424 model_lib_v2.py:707] Step 24400 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.01255909,
#  'Loss/localization_loss': 0.0022329155,
#  'Loss/regularization_loss': 0.081213266,
#  'Loss/total_loss': 0.09600527,
#  'learning_rate': 0.00012330532}
# I1214 06:44:06.697938 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.01255909,
#  'Loss/localization_loss': 0.0022329155,
#  'Loss/regularization_loss': 0.081213266,
#  'Loss/total_loss': 0.09600527,
#  'learning_rate': 0.00012330532}
# INFO:tensorflow:Step 24500 per-step time 0.190s
# I1214 06:44:25.645068 140199886231424 model_lib_v2.py:707] Step 24500 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.06319793,
#  'Loss/localization_loss': 0.0023336941,
#  'Loss/regularization_loss': 0.08121256,
#  'Loss/total_loss': 0.14674419,
#  'learning_rate': 8.5642336e-05}
# I1214 06:44:25.645501 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.06319793,
#  'Loss/localization_loss': 0.0023336941,
#  'Loss/regularization_loss': 0.08121256,
#  'Loss/total_loss': 0.14674419,
#  'learning_rate': 8.5642336e-05}
# INFO:tensorflow:Step 24600 per-step time 0.191s
# I1214 06:44:44.706583 140199886231424 model_lib_v2.py:707] Step 24600 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.009685019,
#  'Loss/localization_loss': 0.0016794399,
#  'Loss/regularization_loss': 0.08121211,
#  'Loss/total_loss': 0.09257657,
#  'learning_rate': 5.4819582e-05}
# I1214 06:44:44.707002 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.009685019,
#  'Loss/localization_loss': 0.0016794399,
#  'Loss/regularization_loss': 0.08121211,
#  'Loss/total_loss': 0.09257657,
#  'learning_rate': 5.4819582e-05}
# INFO:tensorflow:Step 24700 per-step time 0.191s
# I1214 06:45:03.823664 140199886231424 model_lib_v2.py:707] Step 24700 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.014287317,
#  'Loss/localization_loss': 0.002450357,
#  'Loss/regularization_loss': 0.081211835,
#  'Loss/total_loss': 0.097949505,
#  'learning_rate': 3.083944e-05}
# I1214 06:45:03.824062 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.014287317,
#  'Loss/localization_loss': 0.002450357,
#  'Loss/regularization_loss': 0.081211835,
#  'Loss/total_loss': 0.097949505,
#  'learning_rate': 3.083944e-05}
# INFO:tensorflow:Step 24800 per-step time 0.191s
# I1214 06:45:22.876654 140199886231424 model_lib_v2.py:707] Step 24800 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.01133574,
#  'Loss/localization_loss': 0.0019986883,
#  'Loss/regularization_loss': 0.08121172,
#  'Loss/total_loss': 0.094546154,
#  'learning_rate': 1.3706684e-05}
# I1214 06:45:22.877055 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.01133574,
#  'Loss/localization_loss': 0.0019986883,
#  'Loss/regularization_loss': 0.08121172,
#  'Loss/total_loss': 0.094546154,
#  'learning_rate': 1.3706684e-05}
# INFO:tensorflow:Step 24900 per-step time 0.191s
# I1214 06:45:41.960624 140199886231424 model_lib_v2.py:707] Step 24900 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.011845362,
#  'Loss/localization_loss': 0.0020643324,
#  'Loss/regularization_loss': 0.081211686,
#  'Loss/total_loss': 0.09512138,
#  'learning_rate': 3.426075e-06}
# I1214 06:45:41.961028 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.011845362,
#  'Loss/localization_loss': 0.0020643324,
#  'Loss/regularization_loss': 0.081211686,
#  'Loss/total_loss': 0.09512138,
#  'learning_rate': 3.426075e-06}
# INFO:tensorflow:Step 25000 per-step time 0.192s
# I1214 06:46:01.121937 140199886231424 model_lib_v2.py:707] Step 25000 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.020404281,
#  'Loss/localization_loss': 0.0019459132,
#  'Loss/regularization_loss': 0.081211686,
#  'Loss/total_loss': 0.10356188,
#  'learning_rate': 0.0}
# I1214 06:46:01.122354 140199886231424 model_lib_v2.py:708] {'Loss/classification_loss': 0.020404281,
#  'Loss/localization_loss': 0.0019459132,
#  'Loss/regularization_loss': 0.081211686,
#  'Loss/total_loss': 0.10356188,
#  'learning_rate': 0.0}

# %%
pwd
# Out:
# '/content/drive/My Drive/training_demo'

# %%
# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path /content/drive/MyDrive/training_demo/models/my_ssd_resnet101_v1_fpn/pipeline.config --trained_checkpoint_dir /content/drive/MyDrive/training_demo/models/my_ssd_resnet101_v1_fpn --output_directory /content/drive/MyDrive/training_demo/exported_models/my_model
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W1214 06:46:09.415244 140166623000448 deprecation.py:619] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f7a70636610>, because it is not built.
# W1214 06:46:30.798470 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f7a70636610>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f7a70535a50>, because it is not built.
# W1214 06:46:30.976897 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f7a70535a50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a08271510>, because it is not built.
# W1214 06:46:30.977166 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a08271510>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a082bb3d0>, because it is not built.
# W1214 06:46:30.977355 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a082bb3d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f7a082bb0d0>, because it is not built.
# W1214 06:46:30.977518 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f7a082bb0d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a082bb090>, because it is not built.
# W1214 06:46:30.977685 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a082bb090>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08181150>, because it is not built.
# W1214 06:46:30.977863 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08181150>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f7a08456cd0>, because it is not built.
# W1214 06:46:30.978003 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f7a08456cd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a082dd850>, because it is not built.
# W1214 06:46:30.978174 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a082dd850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08129fd0>, because it is not built.
# W1214 06:46:30.978348 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08129fd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f7a082bb2d0>, because it is not built.
# W1214 06:46:30.978509 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f7a082bb2d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a08129b10>, because it is not built.
# W1214 06:46:30.978747 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a08129b10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a082a3650>, because it is not built.
# W1214 06:46:30.978924 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a082a3650>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a7053b7d0>, because it is not built.
# W1214 06:46:30.979063 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a7053b7d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08104a10>, because it is not built.
# W1214 06:46:30.979206 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08104a10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a081048d0>, because it is not built.
# W1214 06:46:30.979369 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a081048d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08104e10>, because it is not built.
# W1214 06:46:30.979589 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08104e10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a081043d0>, because it is not built.
# W1214 06:46:30.979748 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a081043d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08104a50>, because it is not built.
# W1214 06:46:30.979902 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08104a50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a0805d510>, because it is not built.
# W1214 06:46:30.980130 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a0805d510>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a0805d350>, because it is not built.
# W1214 06:46:30.980283 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a0805d350>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a7053b810>, because it is not built.
# W1214 06:46:30.980486 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a7053b810>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a080fef90>, because it is not built.
# W1214 06:46:30.980623 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a080fef90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a081e1f50>, because it is not built.
# W1214 06:46:30.980762 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a081e1f50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a080fe150>, because it is not built.
# W1214 06:46:30.981148 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a080fe150>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a080fec90>, because it is not built.
# W1214 06:46:30.981337 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a080fec90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a080fe7d0>, because it is not built.
# W1214 06:46:30.981486 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a080fe7d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a080fed90>, because it is not built.
# W1214 06:46:30.981661 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a080fed90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a080ef410>, because it is not built.
# W1214 06:46:30.981822 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a080ef410>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a081b8c10>, because it is not built.
# W1214 06:46:30.981962 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a081b8c10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a0803d610>, because it is not built.
# W1214 06:46:30.982131 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a0803d610>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a0803d590>, because it is not built.
# W1214 06:46:30.982315 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a0803d590>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a083d2250>, because it is not built.
# W1214 06:46:30.982481 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a083d2250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a0803d6d0>, because it is not built.
# W1214 06:46:30.982649 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a0803d6d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a0803d2d0>, because it is not built.
# W1214 06:46:30.982815 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a0803d2d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a0803d490>, because it is not built.
# W1214 06:46:30.982972 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a0803d490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a0803de50>, because it is not built.
# W1214 06:46:30.983120 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a0803de50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a7053b850>, because it is not built.
# W1214 06:46:30.983262 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a7053b850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08008590>, because it is not built.
# W1214 06:46:30.983409 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08008590>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a08008490>, because it is not built.
# W1214 06:46:30.983574 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a08008490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08008c50>, because it is not built.
# W1214 06:46:30.983714 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08008c50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a08008a10>, because it is not built.
# W1214 06:46:30.983884 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a08008a10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08008890>, because it is not built.
# W1214 06:46:30.984028 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a08008890>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a080086d0>, because it is not built.
# W1214 06:46:30.984174 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7a080086d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a082ba510>, because it is not built.
# W1214 06:46:31.021043 140166623000448 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7a082ba510>, because it is not built.
# W1214 06:47:06.379006 140166623000448 save.py:268] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 260). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/training_demo/exported_models/my_model/saved_model/assets
# I1214 06:47:14.184646 140166623000448 builder_impl.py:784] Assets written to: /content/drive/MyDrive/training_demo/exported_models/my_model/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to /content/drive/MyDrive/training_demo/exported_models/my_model/pipeline.config
# I1214 06:47:14.971766 140166623000448 config_util.py:254] Writing pipeline config file to /content/drive/MyDrive/training_demo/exported_models/my_model/pipeline.config

# %% [markdown]
# Inferencing My Trained Models

# %%
"""
Object Detection (On Image) From TF2 Saved Model
=====================================
"""

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'    # Suppress TensorFlow logging (1)
import pathlib
import tensorflow as tf
import cv2
import argparse
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# Enable GPU dynamic memory allocation
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# PROVIDE PATH TO IMAGE DIRECTORY
IMAGE_PATHS = '/content/drive/MyDrive/training_demo/images/train/IMG_20211209_143202.jpg'


# PROVIDE PATH TO MODEL DIRECTORY
PATH_TO_MODEL_DIR = '/content/drive/MyDrive/training_demo/exported_models/my_model'

# PROVIDE PATH TO LABEL MAP
PATH_TO_LABELS = '/content/drive/MyDrive/training_demo/annotations/label_map.pbtxt'

# PROVIDE THE MINIMUM CONFIDENCE THRESHOLD
MIN_CONF_THRESH = float(0.60)

# LOAD THE MODEL

import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "/saved_model"

print('Loading model...', end='')
start_time = time.time()

# LOAD SAVED MODEL AND BUILD DETECTION FUNCTION
detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))

# LOAD LABEL MAP DATA FOR PLOTTING

category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS,
                                                                    use_display_name=True)

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.
    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.
    Args:
      path: the file path to the image
    Returns:
      uint8 numpy array with shape (img_height, img_width, 3)
    """
    return np.array(Image.open(path))




print('Running inference for {}... '.format(IMAGE_PATHS), end='')

image = cv2.imread(IMAGE_PATHS)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_expanded = np.expand_dims(image_rgb, axis=0)

# The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
input_tensor = tf.convert_to_tensor(image)
# The model expects a batch of images, so add an axis with `tf.newaxis`.
input_tensor = input_tensor[tf.newaxis, ...]

# input_tensor = np.expand_dims(image_np, 0)
detections = detect_fn(input_tensor)

# All outputs are batches tensors.
# Convert to numpy arrays, and take index [0] to remove the batch dimension.
# We're only interested in the first num_detections.
num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
               for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

image_with_detections = image.copy()

# SET MIN_SCORE_THRESH BASED ON YOU MINIMUM THRESHOLD FOR DETECTIONS
viz_utils.visualize_boxes_and_labels_on_image_array(
      image_with_detections,
      detections['detection_boxes'],
      detections['detection_classes'],
      detections['detection_scores'],
      category_index,
      use_normalized_coordinates=True,
      max_boxes_to_draw=200,
      min_score_thresh=0.5,
      agnostic_mode=False)

print('Done')
# DISPLAYS OUTPUT IMAGE
cv2_imshow(image_with_detections)
# CLOSES WINDOW ONCE KEY IS PRESSED
# Out:
# Loading model...Done! Took 20.008214712142944 seconds
# Running inference for /content/drive/MyDrive/training_demo/images/train/IMG_20211209_143202.jpg... Done
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F66C5750910>
